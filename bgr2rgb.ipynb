# %%
import cv2
import matplotlib.pyplot as plt
img=cv2.imread(r'C:\img\gif-img\fanbing1\sourse\pre_img\output_epoch599.jpg')
im_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
fig = plt.figure()
plt.imshow(im_rgb)

# %%
import os 
lst=os.listdir(r'C:\img\gif-img\fanbing1\sourse\pre_img')
for i in lst:
    img=cv2.imread(r'C:\img\gif-img\fanbing1\sourse\pre_img\{}'.format(i))
    im_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    cv2.imwrite(r'C:\img\gif-img\fanbing1\sourse_rgb\{}'.format(i), im_rgb)
